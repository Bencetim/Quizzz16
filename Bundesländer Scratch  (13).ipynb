# %%
# Liste erstellen
Liste = ["Baden-Württemberg","Bayern","Thüringen","Sachsen","Rheinland-Pfalz","Saarland", "Hessen", "Nordrhein-Westfalen","Brandenburg","Mecklenburg-Vorpommern","Berlin","Sachsen-Anhalt","Schleswig-Holstein","Bremen","Hamburg", "Niedersachsen"]

#Timer
import time
from datetime import datetime

start_time = datetime.now()

from IPython.display import Markdown, display 

def printmd(string): 
    display(Markdown(string)) 
    

from IPython.display import Image 
#score definieren
score = 0
#Methode definieren
def scorehoch(): 
    global score 
    score = score +1 
    
def scorerunter():
    global score
    score = score -1

# %%
# nach Antwort fragen
antwort1 = input ("Wie heißt du?" + " ")


print("Hallo" + " " + antwort1)
time.sleep(1)
print("Willkommen zum Erdkundeunterricht, lass uns beginnen!")
time.sleep(1)
printmd ("**<i>Beginnen wir mit Frage 1!</i>**")
time.sleep(1)
print ("Dein score ist" + " " + str(score))
time.sleep(1)
# Out:
# Wie heißt du? Martina
# Hallo Martina
# Willkommen zum Erdkundeunterricht, lass uns beginnen!
# **<i>Beginnen wir mit Frage 1!</i>**
# Dein score ist 0

# %%
# Frage 1
printmd("**<i>Tippe bei diesen Aufgaben entweder a b oder c ein !</i>** ")
display(Image('https://paardenbed.nl/image/cache/catalog/provincies/duitsland-baden-wurtemberg-280x280.jpg', width=200, height=200))
pass

print ("Welches Bundesland siehts du?")
print ("a" + " " + str(Liste[9]))
print ("b" + " " + str(Liste[3]))
print ("c" + " " + str(Liste[0]))

antwort2 = input("Nenne deine Antwort" + " ")

if antwort2 == "c":
    printmd("Das ist die **richtige** Antwort")
    scorehoch()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
     
    printmd("Das ist leider **falsch** ")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
time.sleep(1)
# Out:
# **<i>Tippe bei diesen Aufgaben entweder a b oder c ein !</i>**
# Welches Bundesland siehts du?
# a Mecklenburg-Vorpommern
# b Sachsen
# c Baden-Württemberg
# Nenne deine Antwort c
# Das ist die **richtige** Antwort
# Dein score ist 1

# %%
#Frage 2

display(Image('https://www.marktcom.de/assets/deutschlandkarte-bayern-kl-23fe10c0d69fc2a985cf08e1a4755d65003675231bcf2cc8297a36d1940af7c5.png', width=200, height=200))
pass

print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[2]))
print ("b" + " " + str(Liste[1]))
print ("c" + " " + str(Liste[6]))

antwort3 = input("Nenne deine Antwort" + " ")

if antwort3 == "b":
    printmd("Das ist die **richitge** Antwort")
    scorehoch() 
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Thüringen
# b Bayern
# c Hessen
# Nenne deine Antwort b
# Das ist die **richitge** Antwort
# Dein score ist 2

# %%
#Frage 3

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Locator_map_Thuringia_in_Germany.svg/757px-Locator_map_Thuringia_in_Germany.svg.png', width=200, height=200))
pass

print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[2]))
print ("b" + " " + str(Liste[0]))
print ("c" + " " + str(Liste[4]))

antwort4 = input("Nenne deine Antwort" + " ")

if antwort4 == "a":
    printmd("Das ist die **richitge** Antwort")
    scorehoch() 
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Thüringen
# b Baden-Württemberg
# c Rheinland-Pfalz
# Nenne deine Antwort a
# Das ist die **richitge** Antwort
# Dein score ist 3

# %%
# Frage 4

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Locator_map_Saxony_in_Germany.svg/1200px-Locator_map_Saxony_in_Germany.svg.png', width=200, height=200))
pass
print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[12]))
print ("b" + " " + str(Liste[7]))
print ("c" + " " + str(Liste[3]))

antwort5 = input("Nenne deine Antwort" + " ")

if antwort5 == "c":
    printmd("Das ist die **richitge** Antwort")
    scorehoch()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Schleswig-Holstein
# b Nordrhein-Westfalen
# c Sachsen
# Nenne deine Antwort c
# Das ist die **richitge** Antwort
# Dein score ist 4

# %%
# Frage 5

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/Locator_map_Mecklenburg-Vorpommern_in_Germany.svg/757px-Locator_map_Mecklenburg-Vorpommern_in_Germany.svg.png', width=200, height=200))
pass
print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[9]))
print ("b" + " " + str(Liste[3]))
print ("c" + " " + str(Liste[0]))

antwort6 = input("Nenne deine Antwort" + " ")

if antwort6 == "a":
    printmd("Das ist die **richitge** Antwort")
    scorehoch() 
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Mecklenburg-Vorpommern
# b Sachsen
# c Baden-Württemberg
# Nenne deine Antwort a
# Das ist die **richitge** Antwort
# Dein score ist 5

# %%
# Frage 6

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/b/bd/Locator_map_Saxony-Anhalt_in_Germany.svg/757px-Locator_map_Saxony-Anhalt_in_Germany.svg.png', width=200, height=200))
pass
print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[3]))
print ("b" + " " + str(Liste[12]))
print ("c" + " " + str(Liste[11]))

antwort7 = input("Nenne deine Antwort" + " ")

if antwort7 == "c":
    printmd("Das ist die **richitge** Antwort")
    scorehoch() 
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Sachsen
# b Schleswig-Holstein
# c Sachsen-Anhalt
# Nenne deine Antwort c
# Das ist die **richitge** Antwort
# Dein score ist 6

# %%
# Frage 7

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Locator_map_North_Rhine-Westphalia_in_Germany.svg/1200px-Locator_map_North_Rhine-Westphalia_in_Germany.svg.png', width=200, height=200))
pass
print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[8]))
print ("b" + " " + str(Liste[7]))
print ("c" + " " + str(Liste[13]))

antwort8 = input("Nenne deine Antwort" + " ")

if antwort8 == "b":
    printmd("Das ist die **richitge** Antwort")
    scorehoch()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))

time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Brandenburg
# b Nordrhein-Westfalen
# c Bremen
# Nenne deine Antwort b
# Das ist die **richitge** Antwort
# Dein score ist 7

# %%
# Frage 8

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Locator_map_Schleswig-Holstein_in_Germany.svg/757px-Locator_map_Schleswig-Holstein_in_Germany.svg.png', width=200, height=200))
pass
print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[12]))
print ("b" + " " + str(Liste[14]))
print ("c" + " " + str(Liste[6]))

antwort8 = input("Nenne deine Antwort" + " ")

if antwort8 == "a":
    printmd("Das ist die **richitge** Antwort")
    scorehoch() 
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Schleswig-Holstein
# b Hamburg
# c Hessen
# Nenne deine Antwort a
# Das ist die **richitge** Antwort
# Dein score ist 8

# %%
# Frage 9

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/4/48/Locator_map_Rhineland-Palatinate_in_Germany.svg/1200px-Locator_map_Rhineland-Palatinate_in_Germany.svg.png', width=200, height=200))
pass
print ("Welches Bundesland ist das?")
print ("a" + " " + str(Liste[2]))
print ("b" + " " + str(Liste[0]))
print ("c" + " " + str(Liste[4]))

antwort9 = input("Nenne deine Antwort" + " ")

if antwort9 == "c":
    printmd("Das ist die **richitge** Antwort")
    scorehoch()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))
    
else:
    printmd("Das ist leider **falsch**")
    scorerunter()
    time.sleep(1)
    print("Dein score ist" + " " + str(score))

time.sleep(1)
# Out:
# Welches Bundesland ist das?
# a Thüringen
# b Baden-Württemberg
# c Rheinland-Pfalz
# Nenne deine Antwort c
# Das ist die **richitge** Antwort
# Dein score ist 9

# %%
import ipywidgets as widgets
import sys
from IPython.display import display
from IPython.display import clear_output
def create_multipleChoice_widget(description, options, correct_answer):
    if correct_answer not in options:
        options.append(correct_answer)
    
    correct_answer_index = options.index(correct_answer)
    
    radio_options = [(words, i) for i, words in enumerate(options)]
    alternativ = widgets.RadioButtons(
        options = radio_options,
        description = '',
        disabled = False
    )
    
    description_out = widgets.Output()
    with description_out:
        print(description)
        
    feedback_out = widgets.Output()
  
    def check_selection(b):
        a = int(alternativ.value)
        global score
        if a==correct_answer_index:
            s = '\x1b[6;30;42m' + "Das ist richtig." + '\x1b[0m' +"\n" #green color
           
            score = score + 1 
            print("Dein score ist" + " " + str(score))
        else:
            s = '\x1b[5;30;41m' + "Das ist leider falsch. " + '\x1b[0m' +"\n" #red color
            
            score = score - 1
            print("Dein score ist" + " " + str(score))
            
        with feedback_out:
            clear_output()
            print(s)
        return
    
   
    
    check = widgets.Button(description="submit")
    check.on_click(check_selection)
    
    
    return widgets.VBox([description_out, alternativ, check, feedback_out])
    
Q1 = create_multipleChoice_widget('Welches Bundesland ist das?',['Saarland','Rheinland-Pfalz','Brandenburg'],'Saarland')

display(Image('https://www.feuerwehrabzeichen-weltweit.de/Landkreise/Saarland/Karte_Bundesland_Saarland.png', width=300, height=300))
pass
display(Q1)

# %%
Q2 = create_multipleChoice_widget('Welches Bundesland ist das?',['Sachsen','Hessen','Berlin'],'Berlin')

display(Image('https://www.feuerwehrabzeichen-weltweit.de/Landkreise/Berlin/Landkarte_Berlin.png', width=300, height=300))
pass
display(Q2)

# %%
Q3 = create_multipleChoice_widget('Welches Bundesland ist das?',['Brandenburg','Bremen','Bayern'],'Brandenburg')

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Locator_map_Brandenburg_in_Germany.svg/757px-Locator_map_Brandenburg_in_Germany.svg.png', width=300, height=300))
pass
display(Q3)

# %%
Q4 = create_multipleChoice_widget('Welches Bundesland ist das?',['Bayern','Hamburg','Hessen'],'Hamburg')

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Locator_map_Hamburg_in_Germany.svg/1200px-Locator_map_Hamburg_in_Germany.svg.png', width=300, height=300))
pass
display(Q4)

# %%
Q5 = create_multipleChoice_widget('Welches Bundesland ist das?',['Niedersachsen','Baden-Württemberg','Nordrhein-Westfalen'],'Niedersachsen')

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Locator_map_Lower-Saxony_in_Germany.svg/1200px-Locator_map_Lower-Saxony_in_Germany.svg.png', width=300, height=300))
pass
display(Q5)

# %%
Q6 = create_multipleChoice_widget('Welches Bundesland ist das?',['Bayern','Schleswig-Holstein','Hessen'],'Hessen')

display(Image('https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Locator_map_Hesse_in_Germany.svg/757px-Locator_map_Hesse_in_Germany.svg.png', width=300, height=300))
pass
display(Q6)

# %%
Q7 = create_multipleChoice_widget('Welches Bundesland ist das?',['Bremen','Hamburg','Nordrhein-Westfalen'],'Bremen')

display(Image('https://www.feuerwehrabzeichen-weltweit.de/Landkreise/Bremen/Landkarte_Bremen.png', width=300, height=300))
pass
display(Q7)

# %%
printmd("**<i>Super, du hast es geschafft!</i>**")
time.sleep(2)
if  score > 11 and score < 17:
    print ("Wow, du bist ein Erdkundegenie," + " " + str(antwort1))
    
if  score < 12 and score > 6:
    print("Das war schon ganz gut, weiter so,"+ " " + str(antwort1))
if  score < 7 and score > -17:
    print ("Du brauchst wohl noch etwas Übung,"+ " " + str(antwort1))
    
print("Dein Score ist" + " " + str(score))
time_elapsed = datetime.now() - start_time
print(f"Du hast folgende Zeit für das Quiz benötigt: {time_elapsed} (h:min:sec) ")
print("Ein guter Spieler braucht zwischen 100 und 120 Sekunden")
# Out:
# **<i>Super, du hast es geschafft!</i>**
# Das war schon ganz gut, weiter so, Martina
# Dein Score ist 9
# Du hast folgende Zeit für das Quiz benötigt: 0:01:22.023538 (h:min:sec)
# Ein guter Spieler braucht zwischen 70 und 80 Sekunden

# %%
import ipywidgets as widgets
import sys
from IPython.display import display
from IPython.display import clear_output
def create_multipleChoice_widget(description, options, correct_answer):
    if correct_answer not in options:
        options.append(correct_answer)
    
    correct_answer_index = options.index(correct_answer)
    
    radio_options = [(words, i) for i, words in enumerate(options)]
    alternativ = widgets.RadioButtons(
        options = radio_options,
        description = '',
        disabled = False
    )
    
    description_out = widgets.Output()
    with description_out:
        print(description)
        
    feedback_out = widgets.Output()
  
    def check_selection(b):
        a = int(alternativ.value)
        if a==correct_answer_index:
            s = '\x1b[6;30;42m' + "Sehr schön, das freut uns!" + '\x1b[0m' +"\n" #green color
         
        else:
            s = '\x1b[5;30;41m' + "Schade, vielleich gefällt es dir beim nächsten Mal besser!  " + '\x1b[0m' +"\n" #red color
            
           
            
        with feedback_out:
            clear_output()
            print(s)
        return
    
   
    
    check = widgets.Button(description="submit")
    check.on_click(check_selection)
    
    
    return widgets.VBox([description_out, alternativ, check, feedback_out])
    
Q1 = create_multipleChoice_widget('Wie hat dir das Quiz gefallen?',['sehr gut','naja, ging so'],'sehr gut')

display(Image('https://cdn.xl.thumbs.canstockphoto.at/eule-zeiger-lehrer-besitz-illustration_csp20847225.jpg', width=300, height=300))
pass
display(Q1)
